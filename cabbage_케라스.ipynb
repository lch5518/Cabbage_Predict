# %%
import pandas as pd
import numpy as np

# %% [markdown]
# # 배추배추

# %%
cd D:\4학년2학기\빅데이터경진대회\data\원천조사가격목록조회

# %% [markdown]
# ## arrary로 만들기

# %%
cabbage = []
for j in range(16,20):
    for i in range(1,13):
        if(j==19 and i==9):break
        if i<10:filename = "원천조사가격정보_20"+ str(j) + "0" + str(i) + ".csv"
        else:filename = "원천조사가격정보_20"+ str(j) + str(i) + ".csv"
        cabbageTemp = pd.read_csv(filename, encoding = 'cp949', engine = 'python')
        arr_cabbage = np.asarray(cabbageTemp)
        cabbage.append(arr_cabbage)
        print(filename)
# Out:
# 원천조사가격정보_201601.csv
# 원천조사가격정보_201602.csv
# 원천조사가격정보_201603.csv
# 원천조사가격정보_201604.csv
# 원천조사가격정보_201605.csv
# 원천조사가격정보_201606.csv
# 원천조사가격정보_201607.csv
# 원천조사가격정보_201608.csv
# 원천조사가격정보_201609.csv
# 원천조사가격정보_201610.csv
# 원천조사가격정보_201611.csv
# 원천조사가격정보_201612.csv
# 원천조사가격정보_201701.csv
# 원천조사가격정보_201702.csv
# 원천조사가격정보_201703.csv
# 원천조사가격정보_201704.csv
# 원천조사가격정보_201705.csv
# 원천조사가격정보_201706.csv
# 원천조사가격정보_201707.csv
# 원천조사가격정보_201708.csv
# 원천조사가격정보_201709.csv
# 원천조사가격정보_201710.csv
# 원천조사가격정보_201711.csv
# 원천조사가격정보_201712.csv
# 원천조사가격정보_201801.csv
# 원천조사가격정보_201802.csv
# 원천조사가격정보_201803.csv
# 원천조사가격정보_201804.csv
# 원천조사가격정보_201805.csv
# 원천조사가격정보_201806.csv
# 원천조사가격정보_201807.csv
# 원천조사가격정보_201808.csv
# 원천조사가격정보_201809.csv
# 원천조사가격정보_201810.csv
# 원천조사가격정보_201811.csv
# 원천조사가격정보_201812.csv
# 원천조사가격정보_201901.csv
# 원천조사가격정보_201902.csv
# 원천조사가격정보_201903.csv
# 원천조사가격정보_201904.csv
# 원천조사가격정보_201905.csv
# 원천조사가격정보_201906.csv
# 원천조사가격정보_201907.csv
# 원천조사가격정보_201908.csv

# %% [markdown]
# ## 데이터 테이블로 만들기

# %%
cabbagedf = []
cabbagedf = pd.DataFrame(cabbagedf)
for j in range(16,20):
    for i in range(1,13):
        if(j==19 and i==9):break
        if i<10:filename = "원천조사가격정보_20"+ str(j) + "0" + str(i) + ".csv"
        else:filename = "원천조사가격정보_20"+ str(j) + str(i) + ".csv"
        cabbageTemp = pd.read_csv(filename, encoding = 'cp949', engine = 'python')
        cabbagedf = cabbagedf.append(cabbageTemp)
        print(filename)
# Out:
# 원천조사가격정보_201601.csv
# 원천조사가격정보_201602.csv
# 원천조사가격정보_201603.csv
# 원천조사가격정보_201604.csv
# 원천조사가격정보_201605.csv
# 원천조사가격정보_201606.csv
# 원천조사가격정보_201607.csv
# 원천조사가격정보_201608.csv
# 원천조사가격정보_201609.csv
# 원천조사가격정보_201610.csv
# 원천조사가격정보_201611.csv
# 원천조사가격정보_201612.csv
# 원천조사가격정보_201701.csv
# 원천조사가격정보_201702.csv
# 원천조사가격정보_201703.csv
# 원천조사가격정보_201704.csv
# 원천조사가격정보_201705.csv
# 원천조사가격정보_201706.csv
# 원천조사가격정보_201707.csv
# 원천조사가격정보_201708.csv
# 원천조사가격정보_201709.csv
# 원천조사가격정보_201710.csv
# 원천조사가격정보_201711.csv
# 원천조사가격정보_201712.csv
# 원천조사가격정보_201801.csv
# 원천조사가격정보_201802.csv
# 원천조사가격정보_201803.csv
# 원천조사가격정보_201804.csv
# 원천조사가격정보_201805.csv
# 원천조사가격정보_201806.csv
# 원천조사가격정보_201807.csv
# 원천조사가격정보_201808.csv
# 원천조사가격정보_201809.csv
# 원천조사가격정보_201810.csv
# 원천조사가격정보_201811.csv
# 원천조사가격정보_201812.csv
# 원천조사가격정보_201901.csv
# 원천조사가격정보_201902.csv
# 원천조사가격정보_201903.csv
# 원천조사가격정보_201904.csv
# 원천조사가격정보_201905.csv
# 원천조사가격정보_201906.csv
# 원천조사가격정보_201907.csv
# 원천조사가격정보_201908.csv

# %%
cabbagedf.shape
# Out:
# (4035683, 24)

# %%
cbg_name = cabbagedf[cabbagedf['조사가격품목명'] == '배추']

# %%
cbg_name.shape
# Out:
# (59553, 24)

# %%
cbg_pt = cbg_name[cbg_name['조사구분명'] == '도매가격']

# %%
cbg_1 = cbg_pt[cbg_pt['조사등급명'] == '상(1등급)']

# %%
cbg_1.shape
# Out:
# (4694, 24)

# %%
cbg_nd = cbg_1[['조사일자','당일조사가격']].groupby('조사일자', as_index=False).agg(np.mean)

# %%
cbg_nd.shape
# Out:
# (879, 2)

# %%
cbg_nd.head()
# Out:
#          조사일자  당일조사가격
# 0  2016-01-04   440.0
# 1  2016-01-05   450.0
# 2  2016-01-06   450.0
# 3  2016-01-07   455.0
# 4  2016-01-08   455.0

# %% [markdown]
# # 기상데이터

# %%
cd D:\4학년2학기\빅데이터경진대회
# Out:
# D:\4학년2학기\빅데이터경진대회

# %%
weather = pd.read_csv("기상.csv", encoding = 'cp949', engine = 'python')

# %%
weather.shape
# Out:
# (134144, 47)

# %%
weather.head()
# Out:
#    지점          일시  평균기온(°C)  최저기온(°C)  최저기온 시각(hhmi)  최고기온(°C)  최고기온 시각(hhmi)  \
# 0  90  2016-01-01       3.6      -2.3            3.0       7.6         1302.0
# 1  90  2016-01-02       8.4       5.0           23.0      11.5         1508.0
# 2  90  2016-01-03       6.7       2.4         1937.0       9.8         1032.0
# 3  90  2016-01-04       5.4       0.8         2350.0       9.0         1348.0
# 4  90  2016-01-05       0.6      -2.6         2228.0       4.4         1337.0
#
#    강수 계속시간(hr)  10분 최다 강수량(mm)  10분 최다강수량 시각(hhmi)     ...       \
# 0          NaN             NaN                 NaN     ...
# 1          NaN             NaN                 NaN     ...
# 2          NaN             NaN                 NaN     ...
# 3          NaN             NaN                 NaN     ...
# 4          NaN             NaN                 NaN     ...
#
#    합계 일사량(MJ/m2)  일 최심신적설(cm)  일 최심신적설 시각(hhmi)  일 최심적설(cm)  일 최심적설 시각(hhmi)  \
# 0            NaN          NaN               NaN         NaN              NaN
# 1            NaN          NaN               NaN         NaN              NaN
# 2            NaN          NaN               NaN         NaN              NaN
# 3            NaN          NaN               NaN         NaN              NaN
# 4            NaN          NaN               NaN         NaN              NaN
#
#    합계 3시간 신적설(cm)  평균 전운량(1/10)  평균 중하층운량(1/10)   기사  안개 계속시간(hr)
# 0             NaN           NaN             NaN  NaN          NaN
# 1             NaN           NaN             NaN  NaN          NaN
# 2             NaN           NaN             NaN  NaN          NaN
# 3             NaN           NaN             NaN  NaN          NaN
# 4             NaN           NaN             NaN  NaN          NaN
#
# [5 rows x 47 columns]

# %%
weather.isnull().sum()
# Out:
# 지점                          0
# 일시                          0
# 평균기온(°C)                  182
# 최저기온(°C)                   20
# 최저기온 시각(hhmi)              20
# 최고기온(°C)                   22
# 최고기온 시각(hhmi)              21
# 강수 계속시간(hr)            122042
# 10분 최다 강수량(mm)         102029
# 10분 최다강수량 시각(hhmi)     111629
# 1시간 최다강수량(mm)          102026
# 1시간 최다 강수량 시각(hhmi)    110792
# 일강수량(mm)                85490
# 최대 순간 풍속(m/s)              91
# 최대 순간 풍속 풍향(16방위)          93
# 최대 순간풍속 시각(hhmi)           91
# 최대 풍속(m/s)                 89
# 최대 풍속 풍향(16방위)             91
# 최대 풍속 시각(hhmi)             89
# 평균 풍속(m/s)                116
# 풍정합(100m)                 128
# 최다풍향(16방위)                344
# 평균 이슬점온도(°C)              283
# 최소 상대습도(%)                 66
# 최소 상대습도 시각(hhmi)           64
# 평균 상대습도(%)                291
# 평균 증기압(hPa)               285
# 평균 현지기압(hPa)              216
# 최고 해면기압(hPa)               49
# 최고 해면기압 시각(hhmi)           47
# 최저 해면기압(hPa)               50
# 최저 해면기압 시각(hhmi)           49
# 평균 해면기압(hPa)              225
# 가조시간(hr)                   15
# 합계 일조시간(hr)               231
# 1시간 최다일사 시각(hhmi)       74861
# 1시간 최다일사량(MJ/m2)        74895
# 합계 일사량(MJ/m2)           74890
# 일 최심신적설(cm)            133323
# 일 최심신적설 시각(hhmi)       133363
# 일 최심적설(cm)             132933
# 일 최심적설 시각(hhmi)        132954
# 합계 3시간 신적설(cm)         133321
# 평균 전운량(1/10)            69430
# 평균 중하층운량(1/10)          70311
# 기사                     112266
# 안개 계속시간(hr)            131801
# dtype: int64

# %%
weather[['일강수량(mm)']].isnull().sum()
# Out:
# 일강수량(mm)    85490
# dtype: int64

# %%
weather_use = weather.groupby('일시', as_index=False).agg(np.mean)

# %%
weather_use
# Out:
#               일시          지점   평균기온(°C)   최저기온(°C)  최저기온 시각(hhmi)   최고기온(°C)  \
# 0     2016-01-01  197.776596   1.781915  -3.614894     575.712766   7.424468
# 1     2016-01-02  197.776596   5.326596   0.591489     655.872340  11.404255
# 2     2016-01-03  197.776596   6.017021   1.238298     900.680851  13.068085
# 3     2016-01-04  197.776596   5.407447   0.426596    1802.585106  10.244681
# 4     2016-01-05  197.776596   0.896809  -2.056383    1852.957447   4.640426
# 5     2016-01-06  197.776596   0.967021  -3.795745     573.340426   5.629787
# 6     2016-01-07  197.776596   0.605319  -2.288298    1302.063830   4.476596
# 7     2016-01-08  197.776596  -0.353191  -3.645745     927.914894   3.967021
# 8     2016-01-09  197.776596   0.789362  -3.657447     491.893617   5.555319
# 9     2016-01-10  197.776596   1.811702  -2.461702    1162.851064   6.810638
# 10    2016-01-11  197.776596  -0.445745  -4.011702    1445.510638   4.495745
# 11    2016-01-12  197.776596  -1.841489  -6.690426     793.148936   3.757447
# 12    2016-01-13  197.776596  -1.095699  -4.673404     554.106383   2.495745
# 13    2016-01-14  197.776596  -0.937234  -5.193617    1238.340426   3.467021
# 14    2016-01-15  197.776596  -0.105319  -5.078723     626.414894   6.274468
# 15    2016-01-16  197.776596   0.925532  -3.962766     451.872340   7.415957
# 16    2016-01-17  197.776596   2.256383  -1.284043     347.053191   5.884043
# 17    2016-01-18  197.776596  -1.779787  -7.014894    2269.808511   3.239362
# 18    2016-01-19  197.776596  -7.023404  -9.281915     744.563830  -4.102128
# 19    2016-01-20  197.776596  -6.446809 -10.536170     771.010638  -1.928723
# 20    2016-01-21  197.776596  -4.436170  -8.067021     514.734043   0.159574
# 21    2016-01-22  197.776596  -3.940426  -9.097872     704.212766   0.892553
# 22    2016-01-23  197.776596  -6.752128 -11.152128    2298.744681  -3.228723
# 23    2016-01-24  197.776596 -10.446809 -13.724468     816.861702  -7.010638
# 24    2016-01-25  197.776596  -6.340426 -12.154255     465.542553  -0.968085
# 25    2016-01-26  197.776596  -1.522581  -6.809574     313.595745   3.514894
# 26    2016-01-27  197.776596   0.343617  -4.594681     942.425532   6.306383
# 27    2016-01-28  197.776596   0.504255  -4.305319     411.042553   3.845745
# 28    2016-01-29  197.776596   2.476596   0.554255     612.489362   4.572340
# 29    2016-01-30  197.776596   2.392553  -1.022340    1914.702128   6.630851
# ...          ...         ...        ...        ...            ...        ...
# 1386  2019-10-18  196.904255  15.163441  10.980851     412.308511  19.292553
# 1387  2019-10-19  196.904255  16.157447  11.787234    1401.021277  22.300000
# 1388  2019-10-20  196.904255  15.097872  10.491489     800.978723  22.376596
# 1389  2019-10-21  196.904255  15.175532   9.550000     552.808511  22.786170
# 1390  2019-10-22  196.904255  15.823404  10.287234     593.968085  22.726596
# 1391  2019-10-23  196.904255  15.945745  12.106383     446.074468  19.896809
# 1392  2019-10-24  196.904255  17.239362  13.598936     933.670213  21.852128
# 1393  2019-10-25  196.904255  16.871277  11.945745     934.446809  22.588298
# 1394  2019-10-26  196.904255  12.831915   8.979787    2194.138298  17.017021
# 1395  2019-10-27  196.904255  10.534043   5.380851    1163.574468  17.229787
# 1396  2019-10-28  196.904255  11.446809   4.520213     575.680851  18.454255
# 1397  2019-10-29  196.904255  13.096809   8.043617    1561.202128  18.670213
# 1398  2019-10-30  196.904255  11.191489   5.603191     747.797872  18.208511
# 1399  2019-10-31  196.904255  13.085106   5.895745     548.351064  20.514894
# 1400  2019-11-01  196.904255  14.150000   8.744681    1375.904255  21.536170
# 1401  2019-11-02  196.904255  13.401064   7.638298     551.595745  19.974468
# 1402  2019-11-03  196.904255  13.651064   9.368085    1262.265957  20.165957
# 1403  2019-11-04  196.904255  12.332979   7.545745    1261.585106  18.724468
# 1404  2019-11-05  196.904255  11.594681   6.178723     934.872340  18.913830
# 1405  2019-11-06  196.904255  11.249462   5.556383     597.776596  18.501064
# 1406  2019-11-07  196.904255  10.724468   5.713830    2052.521277  16.888298
# 1407  2019-11-08  196.904255   7.919149   2.608511     920.904255  15.237234
# 1408  2019-11-09  196.904255   8.508511   1.764894     703.202128  17.130851
# 1409  2019-11-10  196.904255   9.500000   3.073404     476.138298  15.925532
# 1410  2019-11-11  196.904255  12.055914   7.753191    1585.925532  16.874194
# 1411  2019-11-12  196.904255   9.628723   4.837234     885.638298  16.478723
# 1412  2019-11-13  196.904255   9.089362   3.800000     677.510638  14.018085
# 1413  2019-11-14  196.904255   3.876596  -0.577660    2115.861702   9.001064
# 1414  2019-11-15  196.904255   7.156383  -0.985106     324.117021  13.735106
# 1415  2019-11-16  196.904255  10.359574   5.298936    1162.234043  17.096809
#
#       최고기온 시각(hhmi)  강수 계속시간(hr)  10분 최다 강수량(mm)  10분 최다강수량 시각(hhmi)  \
# 0       1447.617021          NaN             NaN                 NaN
# 1       1448.585106     0.300000             NaN                 NaN
# 2       1424.893617          NaN             NaN                 NaN
# 3       1287.989362          NaN             NaN                 NaN
# 4       1284.478723     3.358333             NaN                 NaN
# 5       1410.553191          NaN             NaN                 NaN
# 6       1348.117021     1.448333             NaN                 NaN
# 7       1389.851064     3.767000             NaN                 NaN
# 8       1417.063830     1.376667             NaN                 NaN
# 9       1407.414894     4.073333             NaN                 NaN
# 10      1337.074468    15.250000             NaN                 NaN
# 11      1403.840426     3.256250             NaN                 NaN
# 12      1394.872340     7.591250             NaN                 NaN
# 13      1460.180851     4.654286             NaN                 NaN
# 14      1438.712766     5.560000             NaN                 NaN
# 15      1444.978723     5.508333             NaN                 NaN
# 16      1330.638298     8.913529             NaN                 NaN
# 17       495.829787     8.367143             NaN                 NaN
# 18      1434.946809    15.236364             NaN                 NaN
# 19      1449.819149     5.631250             NaN                 NaN
# 20      1460.925532    10.726667             NaN                 NaN
# 21      1379.936170     8.610000             NaN                 NaN
# 22       435.946809    10.432667             NaN                 NaN
# 23      1505.106383    14.578462             NaN                 NaN
# 24      1528.393617     8.907500             NaN                 NaN
# 25      1439.085106     7.221667             NaN                 NaN
# 26      1448.287234     1.500000             NaN                 NaN
# 27      1402.904255    10.869286             NaN                 NaN
# 28      1370.978723    18.477500             NaN                 NaN
# 29      1338.968085     7.232727             NaN                 NaN
# ...             ...          ...             ...                 ...
# 1386    1305.117021     9.498333        0.726316         1299.478261
# 1387    1389.361702     3.060000        0.200000          549.875000
# 1388    1395.042553          NaN             NaN                 NaN
# 1389    1384.063830          NaN             NaN                 NaN
# 1390    1400.563830     1.515000        0.300000         1803.500000
# 1391    1322.234043     2.276667        0.083333         2098.666667
# 1392    1359.287234     3.897273        0.982051         1539.333333
# 1393    1305.882979     2.001818        0.307692          699.384615
# 1394     986.063830     0.925000        0.063158           36.000000
# 1395    1416.627660     4.500000        3.000000          359.000000
# 1396    1399.851064     1.575000        1.060000         2163.727273
# 1397    1321.734043     0.849091        0.713636          344.045455
# 1398    1418.000000          NaN             NaN                 NaN
# 1399    1410.000000          NaN             NaN                 NaN
# 1400    1362.851064          NaN             NaN                 NaN
# 1401    1378.840426          NaN             NaN                 NaN
# 1402    1334.010638     2.973750        0.100000                 NaN
# 1403    1365.787234     0.600000             NaN                 NaN
# 1404    1373.372340     0.450000             NaN                 NaN
# 1405    1377.244681     2.920000             NaN                 NaN
# 1406    1310.606383     5.585000             NaN                 NaN
# 1407    1429.670213    10.500000             NaN                 NaN
# 1408    1383.191489     6.875000             NaN                 NaN
# 1409    1524.744681     2.601364             NaN                 NaN
# 1410    1372.648936     2.991333             NaN                 NaN
# 1411    1413.191489     4.550000             NaN                 NaN
# 1412    1495.138298     3.330526             NaN                 NaN
# 1413     308.212766     0.586667             NaN                 NaN
# 1414    1473.925532     7.325455             NaN                 NaN
# 1415    1406.308511     1.576000             NaN                 NaN
#
#          ...       1시간 최다일사량(MJ/m2)  합계 일사량(MJ/m2)  일 최심신적설(cm)  \
# 0        ...               1.638718       8.817949          NaN
# 1        ...               1.320769       6.999487          NaN
# 2        ...               1.587179       8.441538          NaN
# 3        ...               1.609744       8.930769          NaN
# 4        ...               1.099744       5.385897          NaN
# 5        ...               1.486410       7.971795          NaN
# 6        ...               1.612821       8.683846          NaN
# 7        ...               1.648974       8.764359     0.566667
# 8        ...               1.629487       9.062564     0.200000
# 9        ...               1.651026       9.178718          NaN
# 10       ...               1.721282       9.453333     2.700000
# 11       ...               1.792821      10.378205     3.900000
# 12       ...               1.537692       7.864103     1.542857
# 13       ...               1.754872       9.556410     2.771429
# 14       ...               1.665641       8.973077     2.550000
# 15       ...               1.432308       7.652308     1.000000
# 16       ...               0.604615       2.981795     0.350000
# 17       ...               1.408205       7.280000     3.460000
# 18       ...               1.687692       9.617692     3.918182
# 19       ...               1.614872       8.739487     1.000000
# 20       ...               1.240513       6.617949    16.000000
# 21       ...               1.704872       9.891282    29.500000
# 22       ...               1.661538       8.745385    10.340000
# 23       ...               1.415641       8.205385     7.216667
# 24       ...               1.858462      10.513077     2.444444
# 25       ...               1.800000       9.353590     0.916667
# 26       ...               1.743590      10.414103          NaN
# 27       ...               0.574872       2.980000     1.200000
# 28       ...               0.462051       2.426410     2.500000
# 29       ...               1.384872       6.858718     4.500000
# ...      ...                    ...            ...          ...
# 1386     ...               1.089545       5.826136          NaN
# 1387     ...               2.420682      14.673864          NaN
# 1388     ...               2.378409      14.306136          NaN
# 1389     ...               2.380909      14.975227          NaN
# 1390     ...               2.249318      13.501591          NaN
# 1391     ...               1.182955       6.424773          NaN
# 1392     ...               1.741364       9.556364          NaN
# 1393     ...               2.135682      11.899773          NaN
# 1394     ...               2.211591      12.918864          NaN
# 1395     ...               2.327955      13.967045          NaN
# 1396     ...               2.274318      13.567045          NaN
# 1397     ...               2.109318      12.267727          NaN
# 1398     ...               2.329545      14.862727          NaN
# 1399     ...               2.208864      13.640227          NaN
# 1400     ...               2.172273      12.886591          NaN
# 1401     ...               1.692273       9.602273          NaN
# 1402     ...               1.845227      10.144773          NaN
# 1403     ...               1.985455      11.230455          NaN
# 1404     ...               2.154091      12.560909          NaN
# 1405     ...               2.078864      12.066364          NaN
# 1406     ...               2.001818      11.103409          NaN
# 1407     ...               2.122326      12.880000          NaN
# 1408     ...               2.029767      12.133409          NaN
# 1409     ...               1.172558       6.385682          NaN
# 1410     ...               1.743721       8.965116          NaN
# 1411     ...               1.808864      10.148636          NaN
# 1412     ...               0.844545       3.773182          NaN
# 1413     ...               2.141818      13.117727          NaN
# 1414     ...               1.604773       9.200227     0.300000
# 1415     ...               1.777727       9.493409          NaN
#
#       일 최심신적설 시각(hhmi)  일 최심적설(cm)  일 최심적설 시각(hhmi)  합계 3시간 신적설(cm)  \
# 0                  NaN         NaN              NaN             NaN
# 1                  NaN         NaN              NaN             NaN
# 2                  NaN         NaN              NaN             NaN
# 3                  NaN         NaN              NaN             NaN
# 4                  NaN         NaN              NaN        3.000000
# 5                  NaN         NaN              NaN             NaN
# 6                  NaN         NaN              NaN             NaN
# 7           677.000000    0.566667       677.000000        0.566667
# 8           600.000000    0.200000       600.000000        0.200000
# 9                  NaN         NaN              NaN             NaN
# 10         1859.000000    2.700000      1859.000000        3.200000
# 11         1740.000000    4.900000      1740.000000        3.900000
# 12         1215.769231    1.985714      1034.384615        1.757143
# 13         1219.000000    2.391667       345.727273        2.914286
# 14          534.500000    6.275000       267.750000        2.550000
# 15         1596.000000    3.500000      1064.333333        1.200000
# 16         1082.500000    4.600000      1078.000000        0.350000
# 17         2031.600000    3.509091      1847.000000        3.650000
# 18         1186.600000    6.345455      1076.600000        3.933333
# 19          950.000000    4.560000       177.900000        1.050000
# 20         2359.000000    4.087500       295.750000       24.400000
# 21         2359.000000   10.200000       472.600000       29.500000
# 22         2060.900000   14.910000      2060.900000       10.800000
# 23         1713.333333   16.741667      1234.333333        7.500000
# 24          934.888889   19.850000       500.400000        2.600000
# 25          856.666667   11.300000       398.153846        0.916667
# 26                 NaN   12.485714         1.000000             NaN
# 27         2044.500000   10.042857       584.857143        1.350000
# 28         1549.250000    8.375000       550.142857        2.360000
# 29         1408.000000   13.375000       429.500000        4.500000
# ...                ...         ...              ...             ...
# 1386               NaN         NaN              NaN             NaN
# 1387               NaN         NaN              NaN             NaN
# 1388               NaN         NaN              NaN             NaN
# 1389               NaN         NaN              NaN             NaN
# 1390               NaN         NaN              NaN             NaN
# 1391               NaN         NaN              NaN             NaN
# 1392               NaN         NaN              NaN             NaN
# 1393               NaN         NaN              NaN             NaN
# 1394               NaN         NaN              NaN             NaN
# 1395               NaN         NaN              NaN             NaN
# 1396               NaN         NaN              NaN             NaN
# 1397               NaN         NaN              NaN             NaN
# 1398               NaN         NaN              NaN             NaN
# 1399               NaN         NaN              NaN             NaN
# 1400               NaN         NaN              NaN             NaN
# 1401               NaN         NaN              NaN             NaN
# 1402               NaN         NaN              NaN             NaN
# 1403               NaN         NaN              NaN             NaN
# 1404               NaN         NaN              NaN             NaN
# 1405               NaN         NaN              NaN             NaN
# 1406               NaN         NaN              NaN             NaN
# 1407               NaN         NaN              NaN             NaN
# 1408               NaN         NaN              NaN             NaN
# 1409               NaN         NaN              NaN             NaN
# 1410               NaN         NaN              NaN             NaN
# 1411               NaN         NaN              NaN             NaN
# 1412               NaN         NaN              NaN             NaN
# 1413               NaN         NaN              NaN             NaN
# 1414        755.000000    0.300000       755.000000        0.300000
# 1415               NaN         NaN              NaN             NaN
#
#       평균 전운량(1/10)  평균 중하층운량(1/10)  안개 계속시간(hr)
# 0         4.513636        3.518182     0.500000
# 1         4.936364        3.731818          NaN
# 2         3.831818        3.250000     6.266667
# 3         3.318182        1.890909     2.830000
# 4         5.636364        2.227273          NaN
# 5         5.513636        3.281818          NaN
# 6         3.922727        3.200000          NaN
# 7         3.563636        3.340909          NaN
# 8         3.859091        3.859091          NaN
# 9         3.322727        2.381818          NaN
# 10        3.450000        1.390909          NaN
# 11        2.963636        2.109091          NaN
# 12        5.181818        5.136364          NaN
# 13        3.772727        3.659091          NaN
# 14        3.095455        3.027273          NaN
# 15        5.136364        3.827273     1.580000
# 16        8.522727        3.800000          NaN
# 17        6.227273        5.722727     2.556667
# 18        3.913636        3.872727          NaN
# 19        4.277273        2.390909          NaN
# 20        6.086364        2.509091          NaN
# 21        5.359091        1.377273          NaN
# 22        5.759091        3.750000          NaN
# 23        3.750000        3.740909          NaN
# 24        2.745455        2.745455          NaN
# 25        4.127273        4.077273          NaN
# 26        2.995455        1.190909          NaN
# 27        8.354545        5.272727     6.415000
# 28        9.145455        5.668182     5.800000
# 29        6.250000        4.213636     3.915000
# ...            ...             ...          ...
# 1386      8.207527        5.559341          NaN
# 1387      2.829032        1.929348     3.250000
# 1388      2.897849        1.703261     5.280000
# 1389      3.317204        1.225000     3.626000
# 1390      4.578495        2.100000     2.450000
# 1391      8.939785        3.834783     2.420000
# 1392      6.616129        4.420652          NaN
# 1393      6.198925        2.694565          NaN
# 1394      6.039785        2.883696          NaN
# 1395      2.255914        0.867391     1.170000
# 1396      4.688172        1.708696     2.670000
# 1397      2.583951        1.526250     2.275000
# 1398      1.018280        0.446739     0.670000
# 1399      2.302151        1.170652     2.920000
# 1400      3.129032        1.385870     4.212500
# 1401      6.213978        2.407609     3.750000
# 1402      5.932258        3.238043     4.806667
# 1403      3.672043        2.328261          NaN
# 1404      2.382796        1.334066     5.170000
# 1405      4.763441        1.585714     3.670000
# 1406      4.312903        2.020879          NaN
# 1407      0.648387        0.412088          NaN
# 1408      0.925806        0.375000          NaN
# 1409      7.523656        3.409890          NaN
# 1410      4.506452        3.205495          NaN
# 1411      3.727957        2.002174     4.335000
# 1412      7.232258        4.872826     6.585000
# 1413      1.107527        0.771739          NaN
# 1414      3.617204        2.259783          NaN
# 1415      3.964516        2.203261     7.240000
#
# [1416 rows x 46 columns]

# %%
weather_use.shape
# Out:
# (1416, 46)

# %%
weather_use.isnull().sum()
# Out:
# 일시                     0
# 지점                     0
# 평균기온(°C)               0
# 최저기온(°C)               0
# 최저기온 시각(hhmi)          0
# 최고기온(°C)               0
# 최고기온 시각(hhmi)          0
# 강수 계속시간(hr)            0
# 10분 최다 강수량(mm)         0
# 10분 최다강수량 시각(hhmi)     0
# 1시간 최다강수량(mm)          0
# 1시간 최다 강수량 시각(hhmi)    0
# 일강수량(mm)               0
# 최대 순간 풍속(m/s)          0
# 최대 순간 풍속 풍향(16방위)      0
# 최대 순간풍속 시각(hhmi)       0
# 최대 풍속(m/s)             0
# 최대 풍속 풍향(16방위)         0
# 최대 풍속 시각(hhmi)         0
# 평균 풍속(m/s)             0
# 풍정합(100m)              0
# 최다풍향(16방위)             0
# 평균 이슬점온도(°C)           0
# 최소 상대습도(%)             0
# 최소 상대습도 시각(hhmi)       0
# 평균 상대습도(%)             0
# 평균 증기압(hPa)            0
# 평균 현지기압(hPa)           0
# 최고 해면기압(hPa)           0
# 최고 해면기압 시각(hhmi)       0
# 최저 해면기압(hPa)           0
# 최저 해면기압 시각(hhmi)       0
# 평균 해면기압(hPa)           0
# 가조시간(hr)               0
# 합계 일조시간(hr)            0
# 1시간 최다일사 시각(hhmi)      0
# 1시간 최다일사량(MJ/m2)       0
# 합계 일사량(MJ/m2)          0
# 일 최심신적설(cm)            0
# 일 최심신적설 시각(hhmi)       0
# 일 최심적설(cm)             0
# 일 최심적설 시각(hhmi)        0
# 합계 3시간 신적설(cm)         0
# 평균 전운량(1/10)           0
# 평균 중하층운량(1/10)         0
# 안개 계속시간(hr)            0
# dtype: int64

# %%
weather_use = weather_use.fillna(0)

# %% [markdown]
# # merge

# %%
cabbge_res = pd.merge(cbg_nd, weather_use, left_on = '조사일자', right_on = '일시')

# %%
cabbge_res.head()
# Out:
#          조사일자  당일조사가격          일시          지점  평균기온(°C)  최저기온(°C)  \
# 0  2016-01-04   440.0  2016-01-04  197.776596  5.407447  0.426596
# 1  2016-01-05   450.0  2016-01-05  197.776596  0.896809 -2.056383
# 2  2016-01-06   450.0  2016-01-06  197.776596  0.967021 -3.795745
# 3  2016-01-07   455.0  2016-01-07  197.776596  0.605319 -2.288298
# 4  2016-01-08   455.0  2016-01-08  197.776596 -0.353191 -3.645745
#
#    최저기온 시각(hhmi)   최고기온(°C)  최고기온 시각(hhmi)  강수 계속시간(hr)     ...       \
# 0    1802.585106  10.244681    1287.989362     0.000000     ...
# 1    1852.957447   4.640426    1284.478723     3.358333     ...
# 2     573.340426   5.629787    1410.553191     0.000000     ...
# 3    1302.063830   4.476596    1348.117021     1.448333     ...
# 4     927.914894   3.967021    1389.851064     3.767000     ...
#
#    1시간 최다일사량(MJ/m2)  합계 일사량(MJ/m2)  일 최심신적설(cm)  일 최심신적설 시각(hhmi)  일 최심적설(cm)  \
# 0          1.609744       8.930769     0.000000               0.0    0.000000
# 1          1.099744       5.385897     0.000000               0.0    0.000000
# 2          1.486410       7.971795     0.000000               0.0    0.000000
# 3          1.612821       8.683846     0.000000               0.0    0.000000
# 4          1.648974       8.764359     0.566667             677.0    0.566667
#
#    일 최심적설 시각(hhmi)  합계 3시간 신적설(cm)  평균 전운량(1/10)  평균 중하층운량(1/10)  안개 계속시간(hr)
# 0              0.0        0.000000      3.318182        1.890909         2.83
# 1              0.0        3.000000      5.636364        2.227273         0.00
# 2              0.0        0.000000      5.513636        3.281818         0.00
# 3              0.0        0.000000      3.922727        3.200000         0.00
# 4            677.0        0.566667      3.563636        3.340909         0.00
#
# [5 rows x 48 columns]

# %%
cabbge_res.shape
# Out:
# (879, 48)

# %%
cabbge_res.to_csv("cabbge_res.csv", mode='w', encoding ='cp949')

# %% [markdown]
# # 주요변수 선택 - R스튜디오에서 aic함수 사용

# %%
cabbge_res.columns
# Out:
# Index(['조사일자', '당일조사가격', '일시', '지점', '평균기온(°C)', '최저기온(°C)', '최저기온 시각(hhmi)',
#        '최고기온(°C)', '최고기온 시각(hhmi)', '강수 계속시간(hr)', '10분 최다 강수량(mm)',
#        '10분 최다강수량 시각(hhmi)', '1시간 최다강수량(mm)', '1시간 최다 강수량 시각(hhmi)',
#        '일강수량(mm)', '최대 순간 풍속(m/s)', '최대 순간 풍속 풍향(16방위)', '최대 순간풍속 시각(hhmi)',
#        '최대 풍속(m/s)', '최대 풍속 풍향(16방위)', '최대 풍속 시각(hhmi)', '평균 풍속(m/s)',
#        '풍정합(100m)', '최다풍향(16방위)', '평균 이슬점온도(°C)', '최소 상대습도(%)',
#        '최소 상대습도 시각(hhmi)', '평균 상대습도(%)', '평균 증기압(hPa)', '평균 현지기압(hPa)',
#        '최고 해면기압(hPa)', '최고 해면기압 시각(hhmi)', '최저 해면기압(hPa)', '최저 해면기압 시각(hhmi)',
#        '평균 해면기압(hPa)', '가조시간(hr)', '합계 일조시간(hr)', '1시간 최다일사 시각(hhmi)',
#        '1시간 최다일사량(MJ/m2)', '합계 일사량(MJ/m2)', '일 최심신적설(cm)', '일 최심신적설 시각(hhmi)',
#        '일 최심적설(cm)', '일 최심적설 시각(hhmi)', '합계 3시간 신적설(cm)', '평균 전운량(1/10)',
#        '평균 중하층운량(1/10)', '안개 계속시간(hr)'],
#       dtype='object')

# %%
cabbge_select = cabbge_res[['일시','평균기온(°C)','최고기온(°C)','일강수량(mm)','최대 순간 풍속(m/s)',
            '최대 풍속(m/s)','평균 풍속(m/s)','풍정합(100m)','평균 이슬점온도(°C)','평균 상대습도(%)',
             '평균 증기압(hPa)','평균 현지기압(hPa)','평균 해면기압(hPa)','1시간 최다일사량(MJ/m2)',
            '합계 일사량(MJ/m2)','평균 중하층운량(1/10)','당일조사가격']]

# %%
cabbge_select.shape
# Out:
# (879, 17)

# %%
cabbge_select.head()
# Out:
#           일시  평균기온(°C)   최고기온(°C)  일강수량(mm)  최대 순간 풍속(m/s)  최대 풍속(m/s)  \
# 0 2016-01-04  5.407447  10.244681  0.000000       8.487234    5.159574
# 1 2016-01-05  0.896809   4.640426  2.026923       7.254255    4.401064
# 2 2016-01-06  0.967021   5.629787  0.000000       8.513830    5.118085
# 3 2016-01-07  0.605319   4.476596  0.008333       9.114894    5.491489
# 4 2016-01-08 -0.353191   3.967021  0.293750       9.243617    5.444681
#
#    평균 풍속(m/s)    풍정합(100m)  평균 이슬점온도(°C)  평균 상대습도(%)  평균 증기압(hPa)  \
# 0    2.350000  2026.680851     -2.997872   59.117021     5.294681
# 1    2.035106  1761.946809    -10.312766   47.179787     3.141489
# 2    2.276596  1968.936170     -7.614894   54.793617     3.644681
# 3    2.676596  2312.776596     -8.175532   54.441489     3.491489
# 4    2.423404  2097.968085     -8.745745   56.604255     3.391489
#
#    평균 현지기압(hPa)  평균 해면기압(hPa)  1시간 최다일사량(MJ/m2)  합계 일사량(MJ/m2)  \
# 0   1009.140426   1022.245745          1.609744       8.930769
# 1   1012.529787   1025.926596          1.099744       5.385897
# 2   1011.035106   1024.431915          1.486410       7.971795
# 3   1010.273404   1023.671277          1.612821       8.683846
# 4   1009.357447   1022.793617          1.648974       8.764359
#
#    평균 중하층운량(1/10)  당일조사가격
# 0        1.890909   440.0
# 1        2.227273   450.0
# 2        3.281818   450.0
# 3        3.200000   455.0
# 4        3.340909   455.0

# %%
cabbge_select.to_csv("cabbge_select.csv", mode='w', encoding ='cp949')

# %%
cabbge_select.dtypes
# Out:
# 일시                  datetime64[ns]
# 평균기온(°C)                   float64
# 최고기온(°C)                   float64
# 일강수량(mm)                   float64
# 최대 순간 풍속(m/s)              float64
# 최대 풍속(m/s)                 float64
# 평균 풍속(m/s)                 float64
# 풍정합(100m)                  float64
# 평균 이슬점온도(°C)               float64
# 평균 상대습도(%)                 float64
# 평균 증기압(hPa)                float64
# 평균 현지기압(hPa)               float64
# 평균 해면기압(hPa)               float64
# 1시간 최다일사량(MJ/m2)           float64
# 합계 일사량(MJ/m2)              float64
# 평균 중하층운량(1/10)             float64
# 당일조사가격                     float64
# dtype: object

# %%
cabbge_select['일시'] = pd.to_datetime(cabbge_select['일시'])
# Out:
# C:\Users\user\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
cabbge_select['일시'] = pd.to_numeric(cabbge_select['일시'])
# Out:
# C:\Users\user\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
cabbge_select_use = cabbge_select[['평균기온(°C)','최고기온(°C)','평균 현지기압(hPa)','평균 중하층운량(1/10)','당일조사가격']]

# %%
cabbge_select_use.head()
# Out:
#    평균기온(°C)   최고기온(°C)  평균 현지기압(hPa)  평균 중하층운량(1/10)  당일조사가격
# 0  5.407447  10.244681   1009.140426        1.890909   440.0
# 1  0.896809   4.640426   1012.529787        2.227273   450.0
# 2  0.967021   5.629787   1011.035106        3.281818   450.0
# 3  0.605319   4.476596   1010.273404        3.200000   455.0
# 4 -0.353191   3.967021   1009.357447        3.340909   455.0

# %%
cabbge_select_use.dtypes
# Out:
# 평균기온(°C)          float64
# 최고기온(°C)          float64
# 평균 현지기압(hPa)      float64
# 평균 중하층운량(1/10)    float64
# 당일조사가격            float64
# dtype: object

# %%
cabbge_select_use.head()
# Out:
#            일시  평균기온(°C)  일강수량(mm)  평균 현지기압(hPa)  당일조사가격
# 0  2016-01-04  5.407447  0.000000   1009.140426   440.0
# 1  2016-01-05  0.896809  2.026923   1012.529787   450.0
# 2  2016-01-06  0.967021  0.000000   1011.035106   450.0
# 3  2016-01-07  0.605319  0.008333   1010.273404   455.0
# 4  2016-01-08 -0.353191  0.293750   1009.357447   455.0

# %%
cabbge_select_use.isnull().sum()
# Out:
# 일시              0
# 평균기온(°C)        0
# 일강수량(mm)        0
# 평균 현지기압(hPa)    0
# 당일조사가격          0
# 월               0
# dtype: int64

# %%
cabbge_select_use['일시'] = pd.to_datetime(cabbge_select_use['일시'])
cabbge_select_use['일시'] = pd.to_numeric(cabbge_select_use['일시'])
# Out:
# C:\Users\user\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.
# C:\Users\user\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
cabbge_select_use['월'] = cabbge_select_use['일시'].str[5:7]
cabbge_select_use['일'] = cabbge_select_use['일시'].str[8:10]
# Out:
# C:\Users\user\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.
# C:\Users\user\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
cabbge_select_use['월일'] = cabbge_select_use['일시'].str[5:7]+cabbge_select_use['일시'].str[8:10]
# Out:
# C:\Users\user\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
cabbge_select_use['월'] = pd.to_numeric(cabbge_select_use['월'])

# %%
cabbge_select_use['월'] = cabbge_select_use['월'].astype('float')
# Out:
# C:\Users\user\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
cabbge_select_use.dtypes
# Out:
# 일시                int64
# 평균기온(°C)        float64
# 일강수량(mm)        float64
# 평균 현지기압(hPa)    float64
# 당일조사가격          float64
# 월               float64
# dtype: object

# %%
cabbge_select_use = cabbge_select_use[['월일','월','일','평균기온(°C)','일강수량(mm)','평균 현지기압(hPa)','당일조사가격']]

# %%
cabbge_select_use.head()
# Out:
#      월일   월   일  평균기온(°C)  일강수량(mm)  평균 현지기압(hPa)  당일조사가격
# 0  0104  01  04  5.407447  0.000000   1009.140426   440.0
# 1  0105  01  05  0.896809  2.026923   1012.529787   450.0
# 2  0106  01  06  0.967021  0.000000   1011.035106   450.0
# 3  0107  01  07  0.605319  0.008333   1010.273404   455.0
# 4  0108  01  08 -0.353191  0.293750   1009.357447   455.0

# %%
np.asarray(cabbge_select_use)
# Out:
# array([[1.00000000e+00, 5.40744681e+00, 0.00000000e+00, 1.00914043e+03,
#         4.40000000e+02],
#        [1.00000000e+00, 8.96808511e-01, 2.02692308e+00, 1.01252979e+03,
#         4.50000000e+02],
#        [1.00000000e+00, 9.67021277e-01, 0.00000000e+00, 1.01103511e+03,
#         4.50000000e+02],
#        ...,
#        [8.00000000e+00, 2.35968085e+01, 4.51566265e+00, 9.95441489e+02,
#         9.60000000e+03],
#        [8.00000000e+00, 2.22170213e+01, 7.62658228e+00, 9.95280851e+02,
#         1.00000000e+04],
#        [8.00000000e+00, 2.26478723e+01, 3.43333333e-01, 9.97506383e+02,
#         1.04000000e+04]])

# %%
cabbge_select_use.to_csv("cabbge_select_use.csv", mode='w', encoding ='cp949')

# %% [markdown]
# # 케라스를 이용하여 예측하기

# %% [markdown]
# ### 목표변수 분리

# %%
data = np.asarray(cabbge_select_use[cabbge_select != cabbge_select_use['당일조사가격']])

# %%
data.shape
# Out:
# (879, 5)

# %%
targets = np.asarray(cabbge_select_use['당일조사가격'])

# %%
targets.shape
# Out:
# (879,)

# %%
targets.shape
# Out:
# (879,)

# %% [markdown]
# ## train/test데이터 나누기

# %%
# 데이터 나누기
cnt = 1
price_train = []
price_test = []

for i in targets:
    if cnt <= 528:
        price_train.append(i)
    else:
        price_test.append(i)
    cnt += 1
    
train_targets = np.asarray(price_train)
test_targets = np.asarray(price_test)

# %%
train_targets.shape
# Out:
# (528,)

# %%
test_targets.shape
# Out:
# (351,)

# %%
type(train_targets)
# Out:
# numpy.ndarray

# %%
train_targets.shape
# Out:
# (528,)

# %%
cnt = 1
price_train = []
price_test = []

for i in data:
    if cnt <= 528:
        price_train.append(i)
    else:
        price_test.append(i)
    cnt += 1
    
train_data = np.asarray(price_train)
test_data = np.asarray(price_test)

# %%
print(train_data.shape)
print(test_data.shape)
print(train_targets.shape)
print(test_targets.shape)
# Out:
# (528, 5)
# (351, 5)
# (528,)
# (351,)

# %%
train_data.shape
# Out:
# (528, 17)

# %%
test_data.shape
# Out:
# (351, 17)

# %%
train_targets.shape
# Out:
# (528,)

# %%
train_data
# Out:
# array([[5.40744681e+00, 1.02446809e+01, 1.00914043e+03, 1.89090909e+00,
#         4.40000000e+02],
#        [8.96808511e-01, 4.64042553e+00, 1.01252979e+03, 2.22727273e+00,
#         4.50000000e+02],
#        [9.67021277e-01, 5.62978723e+00, 1.01103511e+03, 3.28181818e+00,
#         4.50000000e+02],
#        ...,
#        [4.59789474e+00, 1.10136842e+01, 1.01595158e+03, 2.40909091e+00,
#         8.80000000e+03],
#        [5.04842105e+00, 8.92842105e+00, 1.01407053e+03, 6.20909091e+00,
#         8.80000000e+03],
#        [3.25894737e+00, 6.14947368e+00, 1.00544737e+03, 7.39090909e+00,
#         8.70000000e+03]])

# %% [markdown]
# ## 정규화(중요)

# %%
# 정규화
mean = train_data.mean(axis=0)
train_data -= mean
std = train_data.std(axis=0)
train_data /= std

test_data -= mean
test_data /= std

# %%
print(train_data)
print(test_data)
# Out:
# [[-0.65850305 -0.70966707  0.67501793 -0.74446308 -0.55842178]
#  [-1.10350173 -1.25835855  1.12201372 -0.55332826 -0.55330779]
#  [-1.09657486 -1.16149388  0.92489223  0.04590523 -0.55330779]
#  ...
#  [-0.73836971 -0.63437685  1.57328645 -0.45001214  3.71687638]
#  [-0.69392287 -0.8385371   1.32520947  1.70929475  3.71687638]
#  [-0.87046405 -1.11061334  0.18797018  2.38084952  3.66573645]]
# [[-8.53121478e-01 -9.51180786e-01  8.36690786e-01  1.50007961e+00
#    3.66573645e+00]
#  [-4.15507038e-01 -9.17702505e-02  7.10361714e-01 -1.04666273e+00
#    3.92143610e+00]
#  [ 7.14763572e-04  2.05143259e-01  3.10551025e-01 -2.84706351e-01
#    3.61459652e+00]
#  ...
#  [ 1.13597511e+00  9.87235286e-01 -1.13162514e+00  3.67831445e-01
#    4.12599582e+00]
#  [ 9.99851690e-01  7.76320281e-01 -1.15281044e+00  3.52220493e-01
#    4.33055554e+00]
#  [ 1.04235746e+00  1.02254402e+00 -8.59302848e-01 -7.99867769e-01
#    4.53511526e+00]]

# %% [markdown]
# ## 모델빌드

# %%
from keras import models
from keras import layers

def build_model():
    # 동일한 모델을 여러 번 생성할 것이므로 함수를 만들어 사용합니다
    model = models.Sequential()
    model.add(layers.Dense(64, activation='relu',
                           input_shape=(train_data.shape[1],)))
    model.add(layers.Dense(64, activation='relu'))
    model.add(layers.Dense(1))
    model.compile(optimizer='rmsprop', loss='mse', metrics=['accuracy'])#metrics=['mae']
    return model

# %% [markdown]
# ## 교차검증(k-flod)

# %%
import numpy as np

k = 4
num_val_samples = len(train_data) // k
num_epochs = 100
all_scores = []
for i in range(k):
    print('처리중인 폴드 #', i)
    # 검증 데이터 준비: k번째 분할
    val_data = train_data[i * num_val_samples: (i + 1) * num_val_samples]
    val_targets = train_targets[i * num_val_samples: (i + 1) * num_val_samples]

    # 훈련 데이터 준비: 다른 분할 전체
    partial_train_data = np.concatenate(
        [train_data[:i * num_val_samples],
         train_data[(i + 1) * num_val_samples:]],
        axis=0)
    partial_train_targets = np.concatenate(
        [train_targets[:i * num_val_samples],
         train_targets[(i + 1) * num_val_samples:]],
        axis=0)

    # 케라스 모델 구성(컴파일 포함)
    model = build_model()
    # 모델 훈련(verbose=0 이므로 훈련 과정이 출력되지 않습니다)
    model.fit(partial_train_data, partial_train_targets,
              epochs=num_epochs, batch_size=1, verbose=0)
    # 검증 세트로 모델 평가
    val_mse, val_mae = model.evaluate(val_data, val_targets, verbose=0)
    all_scores.append(val_mae)
# Out:
# 처리중인 폴드 # 0
# 처리중인 폴드 # 1
# 처리중인 폴드 # 2
# 처리중인 폴드 # 3

# %%
all_scores
# Out:
# [0.13636364042758942,
#  0.13636364042758942,
#  0.09090909361839294,
#  0.14393939077854156]

# %%
np.mean(all_scores)
# Out:
# 0.12689394131302834

# %%
print(history.history.keys())
# Out:
# dict_keys(['val_loss', 'val_mae', 'loss', 'mae'])

# %%
from keras import backend as K

# 메모리 해제
K.clear_session()

# %%
num_epochs = 300
all_mae_histories = []
for i in range(k):
    print('처리중인 폴드 #', i)
    # 검증 데이터 준비: k번째 분할
    val_data = train_data[i * num_val_samples: (i + 1) * num_val_samples]
    val_targets = train_targets[i * num_val_samples: (i + 1) * num_val_samples]

    # 훈련 데이터 준비: 다른 분할 전체
    partial_train_data = np.concatenate(
        [train_data[:i * num_val_samples],
         train_data[(i + 1) * num_val_samples:]],
        axis=0)
    partial_train_targets = np.concatenate(
        [train_targets[:i * num_val_samples],
         train_targets[(i + 1) * num_val_samples:]],
        axis=0)

    # 케라스 모델 구성(컴파일 포함)
    model = build_model()
    # 모델 훈련(verbose=0 이므로 훈련 과정이 출력되지 않습니다)
    history = model.fit(partial_train_data, partial_train_targets,
                        validation_data=(val_data, val_targets),
                        epochs=num_epochs, batch_size=1, verbose=0)
    val_mse, val_mae = model.evaluate(val_data, val_targets, verbose=0)
    #mae_history = history.history['val_mean_absolute_error']
    all_mae_histories.append(val_mse)
# Out:
# 처리중인 폴드 # 0
# 처리중인 폴드 # 1
# 처리중인 폴드 # 2
# 처리중인 폴드 # 3

# %%
all_mae_histories
# Out:
# [45.29183234590472, 10.014104067376167, 587.3149026234945, 10.556674726081617]

# %%
test_data
# Out:
# array([[-8.53121478e-01, -9.51180786e-01,  8.36690786e-01,
#          1.50007961e+00,  3.66573645e+00],
#        [-4.15507038e-01, -9.17702505e-02,  7.10361714e-01,
#         -1.04666273e+00,  3.92143610e+00],
#        [ 7.14763572e-04,  2.05143259e-01,  3.10551025e-01,
#         -2.84706351e-01,  3.61459652e+00],
#        ...,
#        [ 1.13597511e+00,  9.87235286e-01, -1.13162514e+00,
#          3.67831445e-01,  4.12599582e+00],
#        [ 9.99851690e-01,  7.76320281e-01, -1.15281044e+00,
#          3.52220493e-01,  4.33055554e+00],
#        [ 1.04235746e+00,  1.02254402e+00, -8.59302848e-01,
#         -7.99867769e-01,  4.53511526e+00]])

# %%
test_targets
# Out:
# array([ 8700.,  9200.,  8600.,  8900.,  8800.,  8300.,  8300.,  8200.,
#         8400.,  9000.,  9200.,  9200.,  9100.,  8900.,  8600.,  8500.,
#         8500.,  8500.,  8200.,  8300.,  7900.,  8000.,  8300.,  8300.,
#         8400.,  8200.,  8300.,  8400.,  8100.,  8000.,  8000.,  8200.,
#         8200.,  8200.,  7900.,  7800.,  8000.,  8000.,  7800.,  7900.,
#         8300.,  7050.,  7050.,  6700.,  6630.,  6780.,  6780.,  6780.,
#         6750.,  6000.,  5400.,  5300.,  5300.,  5200.,  5200.,  5200.,
#         5100.,  4900.,  4900.,  4900.,  5000.,  5500.,  5600.,  6000.,
#         6000.,  5800.,  5900.,  6400.,  7066.,  6666.,  6866.,  6932.,
#         6800.,  6700.,  6600.,  7200.,  7300.,  8600.,  8800.,  9200.,
#         9500.,  9510., 10000., 10600., 13400., 14720., 16200., 15800.,
#        17000., 16000., 15600., 14800., 15200., 15600., 15000., 15200.,
#        15000., 15400., 17000., 18400., 19800., 20400., 21000., 22800.,
#        25000., 23600., 24600., 23000., 21800., 20200., 19400., 17000.,
#        16400., 16200., 15400., 15200., 15800., 16000., 15600., 15000.,
#        14800., 14400., 14400., 13800., 14000., 12600., 11800., 11000.,
#        10200.,  8700.,  9100., 10000.,  9000.,  8400.,  8100.,  8066.,
#         8266.,  8100.,  7900.,  8100.,  8200.,  7800.,  7800.,  7800.,
#         7800.,  7800.,  7800.,  7800.,  7800.,  7900.,  8100.,  8300.,
#         8100.,  8200.,  7600.,  7600.,  7800.,  7800.,  7200.,  7400.,
#         7200.,  7200.,  7000.,  7500.,  7000.,  6400.,  6600.,  6600.,
#         6800.,  6632.,  6500.,  6566.,  6700.,  6966.,  6966.,  6966.,
#         6466.,  6100.,  5700.,  5600.,  5600.,  5600.,  5600.,  5800.,
#         5466.,  5466.,  5532.,  5532.,  5800.,  5700.,  5800.,  5300.,
#         5100.,  5100.,  5000.,  4600.,  4800.,  4780.,  4600.,  4500.,
#         4500.,  4400.,  4600.,  4300.,  4300.,  4400.,  4400.,  4400.,
#         4500.,  4300.,  4300.,  4200.,  4120.,  4120.,  4200.,  4120.,
#         4220.,  4000.,  4000.,  4000.,  4000.,  4080.,  3680.,  3700.,
#         3700.,  3600.,  3700.,  3700.,  3800.,  3800.,  3800.,  3800.,
#         3800.,  3800.,  3800.,  3800.,  3800.,  3760.,  3760.,  3600.,
#         3600.,  3700.,  3700.,  3660.,  3660.,  3660.,  3660.,  3620.,
#         3400.,  3340.,  3340.,  3340.,  3340.,  3340.,  3240.,  3240.,
#         3340.,  3340.,  3340.,  3340.,  3340.,  3340.,  3340.,  3440.,
#         3500.,  3640.,  3640.,  3640.,  3540.,  3540.,  3540.,  3610.,
#         3640.,  3690.,  3600.,  3600.,  3760.,  3610.,  3900.,  4600.,
#         4000.,  4020.,  4070.,  4020.,  4100.,  4200.,  4300.,  4160.,
#         4160.,  4320.,  4640.,  4640.,  5060.,  5060.,  5060.,  5500.,
#         6000.,  6200.,  6100.,  6300.,  6200.,  6000.,  6000.,  6000.,
#         5900.,  5900.,  6700.,  7600.,  7600.,  7400.,  7100.,  6700.,
#         6900.,  7000.,  7400.,  7500.,  8200.,  8700.,  7600.,  7600.,
#         7200.,  6700.,  6900.,  7500.,  6900.,  7100.,  7000.,  7400.,
#         7400.,  7200.,  7800.,  8500.,  8300.,  8000.,  8200.,  9400.,
#         9000.,  8400.,  8200.,  8200.,  8800.,  8200.,  8200.,  8400.,
#         8800.,  8800.,  9400.,  9600.,  9600., 10000., 10400.])

# %%
# 새롭게 컴파인된 모델을 얻습니다
model = build_model()
# 전체 데이터로 훈련시킵니다
model.fit(train_data, train_targets,
          epochs=100, batch_size=16, verbose=0)
test_mse_score, test_mae_score = model.evaluate(test_data, test_targets)
# Out:
# 351/351 [==============================] - 0s 191us/step

# %%
test_mse_score
# Out:
# 39484.231183043914

# %%
test_mae_score
# Out:
# 90.08833312988281

# %%
np.sqrt(test_mse_score)
# Out:
# 198.7063944191125

# %%
test_data[0:2]
# Out:
# array([[-0.85312148, -0.95118079,  0.83669079,  1.50007961,  3.66573645],
#        [-0.41550704, -0.09177025,  0.71036171, -1.04666273,  3.9214361 ]])

# %%
test_targets[1]
# Out:
# 9200.0

# %%
xhat = test_data[1:2]
yhat = model.predict(xhat)
print('## yhat ##')
print(xhat,yhat)
# Out:
# ## yhat ##
# [[-0.41550704 -0.09177025  0.71036171 -1.04666273  3.9214361 ]] [[9177.281]]

# %%
yhat[0][0]
# Out:
# 9177.281

# %%
xhat = test_data[0]
xhat
# Out:
# array([-0.85312148, -0.95118079,  0.83669079,  1.50007961,  3.66573645])

# %%
len(test_targets)
# Out:
# 351

# %%
x = []
y = []
for i in range(351):
    xhat = test_data[i:i+1] # 평균기온, 최고온도, 평균 현지기압, 평균 중하층운량
    yhat = model.predict(xhat)
    x.append(test_targets[i])
    y.append(yhat[0][0])

# %%
res = pd.DataFrame(data = {'실제가격' : x,'예측가격' : y})

# %%
res.head()
# Out:
#      실제가격         예측가격
# 0  8700.0  8677.036133
# 1  9200.0  9177.281250
# 2  8600.0  8580.107422
# 3  8900.0  8879.729492
# 4  8800.0  8780.145508

# %%
xhat = test_data[i:i+1] # 평균기온, 최고온도, 평균 현지기압, 평균 중하층운량
yhat = model.predict(xhat)

# %%
import matplotlib.pyplot as plt

# %%
# matplotlib 폰트설정
# plt.rc('font', family='NanumGothicOTF') # For MacOS
plt.rc('font', family='NanumGothic') # For Windows
print(plt.rcParams['font.family'])
# Out:
# ['NanumGothic']

# %%
plt.rcParams["figure.figsize"] = (12,8)
plt.title("배추가격 예측하기")
plt.xlabel('날짜')
plt.ylabel('가격')
plt.plot(res['실제가격'], lw=1, label='실제가격')
plt.plot(res['예측가격'], ls='--',lw=0.9, label='예측가격')
plt.legend(loc=1)
plt.show()
